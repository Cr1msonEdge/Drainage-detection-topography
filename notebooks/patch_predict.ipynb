# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import os
import sys
project_root = os.path.abspath(os.path.join('..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import warnings
warnings.simplefilter("ignore", UserWarning)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
from engine.data_setup import *
from helper.models.deeplab_mobilenet import *
# %matplotlib inline

# %% [markdown]
# ## 4 channels

# %%
model = DeepLab.load_model('DeepLabV3-20250510-235017.pt')

# %%
dataset = get_dataset(mode='test', name='ver8')
# test 76 94 105
# val 43 97

# %%
print([i for i in range(len(dataset)) if dataset[i][1].sum() != 0])
# Out:
# [3, 5, 6, 11, 13, 15, 16, 21, 22, 30, 41, 42, 43, 49, 55, 56, 59, 72, 88, 91, 93, 97, 98, 106, 107, 111, 116, 119, 127, 130, 132, 135, 145, 153, 155, 162, 163, 164, 166, 170, 177, 182, 184, 185, 193, 194, 195, 200, 202, 206, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363
# ...

# %%
i = 43
res = model.predict(dataset[i][0], dataset[i][1], device='cuda', show=True)

# %% [markdown]
# ## 3 channels

# %%
dataset3 = get_dataset(mode='test', name='ver8', channels=3)
model3 = DeepLab.load_model('DeepLabV3-20250510-205850.pt')
print([i for i in range(len(dataset)) if dataset[i][1].sum() != 0])
# Out:
# [3, 5, 6, 11, 13, 15, 16, 21, 22, 30, 41, 42, 43, 49, 55, 56, 59, 72, 88, 91, 93, 97, 98, 106, 107, 111, 116, 119, 127, 130, 132, 135, 145, 153, 155, 162, 163, 164, 166, 170, 177, 182, 184, 185, 193, 194, 195, 200, 202, 206, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363
# ...

# %%
# 211
res = model3.predict(dataset3[i][0], dataset3[i][1], device='cuda', show=True)
