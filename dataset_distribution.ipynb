# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

image_patches = np.load('image_patches.npy')  # (N, 256, 256, 4)
mask_patches = np.load('mask_patches.npy')  # (N, 256, 256)

assert image_patches.shape[0] == mask_patches.shape[0], "Number of images and masks is not equal"

# %%
from helper.utilities import *

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

mask_percentages = [calculate_mask_percentage(i) for i in mask_patches]

plt.figure(figsize=(8, 5))
plt.hist(mask_percentages, bins=20, color='skyblue', edgecolor='black')
plt.title('Mask percentage distribution')
plt.xlabel('Mask percentage')
plt.ylabel('Number of masks')
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(mask_percentages, bins=20, kde=True, color='skyblue')
plt.title('Mask percentage distribution (KDE)')
plt.xlabel('Mask percentage')
plt.ylabel('Number of masks')
plt.show()

# %%
mask_bins = [get_bin(i, max_bins=5, top_bin_percentage=10) for i in mask_patches]

plt.figure(figsize=(8, 5))
plt.xticks([0, 1, 2, 3, 4, 5])

plt.hist(mask_bins, bins=5, color='skyblue', edgecolor='black')
plt.title('Mask bins distribution')
plt.xlabel('Number of bin')
plt.ylabel('Number of masks')
plt.show()
